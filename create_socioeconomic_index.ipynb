# %%
import pandas as pd

# %%
econ_df = pd.read_csv('data/socioeconomic_factors.csv', sep=";")

# %%
new_cols = [col for col in econ_df.columns if ("2021" in col or not "20" in col)]

# %%
econ_df = econ_df[new_cols]
econ_df
# Out:
#                              Kommune       GKZ           ARS  \
# 0                      Ahrweiler, LK   7131000   71310000000
# 1              Aichach-Friedberg, LK   9771000   97710000000
# 2                Alb-Donau-Kreis, LK   8425000   84250000000
# 3               Altenburger Land, LK  16077000  160770000000
# 4      Altenkirchen (Westerwald), LK   7132000   71320000000
# ..                               ...       ...           ...
# 289                 Wolfenb�ttel, LK   3158000   31580000000
# 290  Wunsiedel im Fichtelgebirge, LK   9479000   94790000000
# 291                     W�rzburg, LK   9679000   96790000000
# 292              Zollernalbkreis, LK   8417000   84170000000
# 293                      Zwickau, LK  14524000  145240000000
#
#             Bundesland 2021\nLangzeitarbeitslosenquote (%)  \
# 0      Rheinland-Pfalz                                 1,7
# 1               Bayern                                 0,8
# 2    Baden-W�rttemberg                                 0,9
# 3            Th�ringen                                 3,6
# 4      Rheinland-Pfalz                                 2,6
# ..                 ...                                 ...
# 289      Niedersachsen                                 2,4
# 290             Bayern                                 1,8
# 291             Bayern                                 0,7
# 292  Baden-W�rttemberg                                 1,8
# 293            Sachsen                                 2,4
#
#     2021\nAnteil 65- bis 79-J�hrige (%) 2021\nAnteil ab 80-J�hrige (%)  \
# 0                                  16,6                            8,5
# 1                                  13,9                            6,5
# 2                                  13,4                            6,5
# 3                                  21,1                           10,6
# 4                                  15,6                            7,4
# ..                                  ...                            ...
# 289                                16,2                            8,2
# 290                                17,8                            9,0
# 291                                15,6                            6,9
# 292                                14,9                            7,7
# 293                                20,0                           10,0
#
#      2021\nKaufkraft (Euro/Haushalt)  \
# 0                             52.059
# 1                             61.567
# 2                             62.198
# 3                             44.095
# 4                             54.623
# ..                               ...
# 289                           54.245
# 290                           48.195
# 291                           60.274
# 292                           56.696
# 293                           46.317
#
#     2021\nHaushalte mit niedrigem Einkommen (%)  \
# 0                                          38,7
# 1                                          28,1
# 2                                          31,8
# 3                                          53,6
# 4                                          41,8
# ..                                          ...
# 289                                        43,2
# 290                                        45,6
# 291                                        39,0
# 292                                        32,9
# 293                                        51,6
#
#      2021\nVerschuldung im Kernhaushalt (Euro je Einwohner:in)  \
# 0                                                1.743
# 1                                              621.000
# 2                                              425.000
# 3                                              577.000
# 4                                                2.463
# ..                                                 ...
# 289                                              1.616
# 290                                              2.553
# 291                                            712.000
# 292                                            583.000
# 293                                            346.000
#
#      2021\nAllgemeine Deckungsmittel (Euro je Einwohner:in)
# 0                                                1.597
# 1                                                1.798
# 2                                                1.946
# 3                                                1.758
# 4                                                1.657
# ..                                                 ...
# 289                                              1.810
# 290                                              1.938
# 291                                              1.702
# 292                                              1.999
# 293                                              1.676
#
# [294 rows x 11 columns]

# %%
for col in econ_df.columns:
    if "2021" not in col:
        continue
    try:
        # print(econ_df[col].str.replace(",", "."))
        econ_df[col] = econ_df[col].str.replace(",", ".").astype(float)
    except:
        print("column not string")
# Out:
# column not string

# %%
#econ_df["2021\nAnteil 65- bis 79-J�hrige (%)"] = econ_df["2021\nAnteil 65- bis 79-J�hrige (%)"]
# TODO: Convert to float!!!
# econ_df["2021\nAnteil 65- bis 79-J�hrige (%)"] = econ_df["2021\nAnteil 65- bis 79-J�hrige (%)"].replace(",", ".")
# econ_df["2021\nAnteil ab 80-J�hrige (%)"] = econ_df["2021\nAnteil ab 80-J�hrige (%)"].replace(",", ".")
econ_df["2021\nAnteil ab 65-J�hrige (%)"] = econ_df["2021\nAnteil 65- bis 79-J�hrige (%)"] + econ_df["2021\nAnteil ab 80-J�hrige (%)"]

cols = econ_df.columns

econ_df = econ_df[list(set(econ_df.columns).difference(set(["2021\nAnteil ab 80-J�hrige (%)", "2021\nAnteil 65- bis 79-J�hrige (%)", "2021\nKaufkraft (Euro/Haushalt)"])))]
econ_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\jimma\Documents\GitHub\data4good\venv\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2021\nAnteil 65- bis 79-J�hrige (%)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[85], line 5
#       1 #econ_df["2021\nAnteil 65- bis 79-J�hrige (%)"] = econ_df["2021\nAnteil 65- bis 79-J�hrige (%)"]
#       2 # TODO: Convert to float!!!
#       3 # econ_df["2021\nAnteil 65- bis 79-J�hrige (%)"] = econ_df["2021\nAnteil 65- bis 79-J�hrige (%)"].replace(",", ".")
#       4 # econ_df["2021\nAnteil ab 80-J�hrige (%)"] = econ_df["2021\nAnteil ab 80-J�hrige (%)"].replace(",", ".")
# ----> 5 econ_df["2021\nAnteil ab 65-J�hrige (%)"] = econ_df["2021\nAnteil 65- bis 79-J�hrige (%)"] + econ_df["2021\nAnteil ab 80-J�hrige (%)"]
#       7 cols = econ_df.columns
#       9 econ_df = econ_df[list(set(econ_df.columns).difference(set(["2021\nAnteil ab 80-J�hrige (%)", "2021\nAnteil 65- bis 79-J�hrige (%)", "2021\nKaufkraft (Euro/Haushalt)"])))]
#
# File c:\Users\jimma\Documents\GitHub\data4good\venv\lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\jimma\Documents\GitHub\data4good\venv\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: '2021\nAnteil 65- bis 79-J�hrige (%)'

# %%
econ_df["2021\nHaushalte mit niedrigem Einkommen (%)"][:5]
# Out:
# 0    38.7
# 1    28.1
# 2    31.8
# 3    53.6
# 4    41.8
# Name: 2021\nHaushalte mit niedrigem Einkommen (%), dtype: float64

# %%
econ_df["2021\nAnteil ab 65-J�hrige (%)"][:5]
# Out:
# 0    25.1
# 1    20.4
# 2    19.9
# 3    31.7
# 4    23.0
# Name: 2021\nAnteil ab 65-J�hrige (%), dtype: float64

# %%
# normalize the factors
for col in econ_df.columns:
    if "2021" not in col:
        continue
    econ_df[f"{col}_normalized"] = econ_df[col] / econ_df[col].max()

econ_df["socio_economic_index"] = econ_df["2021\nHaushalte mit niedrigem Einkommen (%)"] + econ_df["2021\nAnteil ab 65-J�hrige (%)"] # + econ_df["2021\nVerschuldung im Kernhaushalt (Euro je Einwohner:in)"] + econ_df["2021\nLangzeitarbeitslosenquote (%)"] - econ_df["2021\nAllgemeine Deckungsmittel (Euro je Einwohner:in)"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\jimma\Documents\GitHub\data4good\venv\lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 5
#       3     if "2021" not in col:
#       4         continue
# ----> 5     econ_df[f"{col}_normalized"] = econ_df[col] / econ_df[col].max()
#       7 econ_df["socio_economic_index"] = econ_df["2021\nHaushalte mit niedrigem Einkommen (%)"] + econ_df["2021\nAnteil ab 65-J�hrige (%)"] # + econ_df["2021\nVerschuldung im Kernhaushalt (Euro je Einwohner:in)"] + econ_df["2021\nLangzeitarbeitslosenquote (%)"] - econ_df["2021\nAllgemeine Deckungsmittel (Euro je Einwohner:in)"]
#
# File c:\Users\jimma\Documents\GitHub\data4good\venv\lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\jimma\Documents\GitHub\data4good\venv\lib\site-packages\pandas\core\arraylike.py:210, in OpsMixin.__truediv__(self, other)
#     208 @unpack_zerodim_and_defer("__truediv__")
#     209 def __truediv__(self, other):
# --> 210     return self._arith_method(other, operator.truediv)
#
# File c:\Users\jimma\Documents\GitHub\data4good\venv\lib\site-packages\pandas\core\series.py:6135, in Series._arith_method(self, other, op)
#    6133 def _arith_method(self, other, op):
#    6134     self, other = self._align_for_op(other)
# -> 6135     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File c:\Users\jimma\Documents\GitHub\data4good\venv\lib\site-packages\pandas\core\base.py:1382, in IndexOpsMixin._arith_method(self, other, op)
#    1379     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1381 with np.errstate(all="ignore"):
# -> 1382     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1384 return self._construct_result(result, name=res_name)
#
# File c:\Users\jimma\Documents\GitHub\data4good\venv\lib\site-packages\pandas\core\ops\array_ops.py:283, in arithmetic_op(left, right, op)
#     279     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     281     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     282     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 283     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     285 return res_values
#
# File c:\Users\jimma\Documents\GitHub\data4good\venv\lib\site-packages\pandas\core\ops\array_ops.py:227, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 except TypeError:
#     220     if not is_cmp and (
#     221         left.dtype == object or getattr(right, "dtype", None) == object
#     222     ):
#    (...)
#     225         # Don't do this for comparisons, as that will handle complex numbers
#     226         #  incorrectly, see GH#32047
# --> 227         result = _masked_arith_op(left, right, op)
#     228     else:
#     229         raise
#
# File c:\Users\jimma\Documents\GitHub\data4good\venv\lib\site-packages\pandas\core\ops\array_ops.py:182, in _masked_arith_op(x, y, op)
#     179         mask = np.where(y == 1, False, mask)
#     181     if mask.any():
# --> 182         result[mask] = op(xrav[mask], y)
#     184 np.putmask(result, ~mask, np.nan)
#     185 result = result.reshape(x.shape)  # 2D compat
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
# make overall index
