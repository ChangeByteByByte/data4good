# %%
import pandas as pd

# %%
econ_df = pd.read_csv('data/socioeconomic_factors.csv', sep=";")

# %%
new_cols = [col for col in econ_df.columns if ("2021" in col or not "20" in col)]

# %%
econ_df = econ_df[new_cols]
econ_df
# Out:
#                              Kommune       GKZ           ARS  \
# 0                      Ahrweiler, LK   7131000   71310000000
# 1              Aichach-Friedberg, LK   9771000   97710000000
# 2                Alb-Donau-Kreis, LK   8425000   84250000000
# 3               Altenburger Land, LK  16077000  160770000000
# 4      Altenkirchen (Westerwald), LK   7132000   71320000000
# ..                               ...       ...           ...
# 289                 Wolfenbüttel, LK   3158000   31580000000
# 290  Wunsiedel im Fichtelgebirge, LK   9479000   94790000000
# 291                     Würzburg, LK   9679000   96790000000
# 292              Zollernalbkreis, LK   8417000   84170000000
# 293                      Zwickau, LK  14524000  145240000000
#
#             Bundesland 2021\r\nLangzeitarbeitslosenquote (%)  \
# 0      Rheinland-Pfalz                                   1,7
# 1               Bayern                                   0,8
# 2    Baden-Württemberg                                   0,9
# 3            Thüringen                                   3,6
# 4      Rheinland-Pfalz                                   2,6
# ..                 ...                                   ...
# 289      Niedersachsen                                   2,4
# 290             Bayern                                   1,8
# 291             Bayern                                   0,7
# 292  Baden-Württemberg                                   1,8
# 293            Sachsen                                   2,4
#
#     2021\r\nAnteil 65- bis 79-Jährige (%) 2021\r\nAnteil ab 80-Jährige (%)  \
# 0                                    16,6                              8,5
# 1                                    13,9                              6,5
# 2                                    13,4                              6,5
# 3                                    21,1                             10,6
# 4                                    15,6                              7,4
# ..                                    ...                              ...
# 289                                  16,2                              8,2
# 290                                  17,8                              9,0
# 291                                  15,6                              6,9
# 292                                  14,9                              7,7
# 293                                  20,0                             10,0
#
#      2021\r\nKaufkraft (Euro/Haushalt)  \
# 0                               52.059
# 1                               61.567
# 2                               62.198
# 3                               44.095
# 4                               54.623
# ..                                 ...
# 289                             54.245
# 290                             48.195
# 291                             60.274
# 292                             56.696
# 293                             46.317
#
#     2021\r\nHaushalte mit niedrigem Einkommen (%)  \
# 0                                            38,7
# 1                                            28,1
# 2                                            31,8
# 3                                            53,6
# 4                                            41,8
# ..                                            ...
# 289                                          43,2
# 290                                          45,6
# 291                                          39,0
# 292                                          32,9
# 293                                          51,6
#
#      2021\r\nVerschuldung im Kernhaushalt (Euro je Einwohner:in)  \
# 0                                                1.743
# 1                                              621.000
# 2                                              425.000
# 3                                              577.000
# 4                                                2.463
# ..                                                 ...
# 289                                              1.616
# 290                                              2.553
# 291                                            712.000
# 292                                            583.000
# 293                                            346.000
#
#      2021\r\nAllgemeine Deckungsmittel (Euro je Einwohner:in)
# 0                                                1.597
# 1                                                1.798
# 2                                                1.946
# 3                                                1.758
# 4                                                1.657
# ..                                                 ...
# 289                                              1.810
# 290                                              1.938
# 291                                              1.702
# 292                                              1.999
# 293                                              1.676
#
# [294 rows x 11 columns]

# %%
import numpy as np

# %%
econ_df.drop("2021\nLangzeitarbeitslosenquote (%)", axis=1, inplace=True)

# %%
for col in econ_df.columns:
    if "2021" not in col:
        continue
    try:
        # print(econ_df[col].str.replace(",", "."))
        econ_df[col] = econ_df[col].str.replace(",", ".").astype(float)
    except:
        print("column not string")
# Out:
# column not string
# column not string
# column not string

# %%
#econ_df["2021\nAnteil 65- bis 79-J�hrige (%)"] = econ_df["2021\nAnteil 65- bis 79-J�hrige (%)"]
# TODO: Convert to float!!!
# econ_df["2021\nAnteil 65- bis 79-J�hrige (%)"] = econ_df["2021\nAnteil 65- bis 79-J�hrige (%)"].replace(",", ".")
# econ_df["2021\nAnteil ab 80-J�hrige (%)"] = econ_df["2021\nAnteil ab 80-J�hrige (%)"].replace(",", ".")
econ_df["2021\nAnteil ab 65-J�hrige (%)"] = econ_df["2021\nAnteil 65- bis 79-J�hrige (%)"] + econ_df["2021\nAnteil ab 80-J�hrige (%)"]

cols = econ_df.columns

econ_df = econ_df[list(set(econ_df.columns).difference(set(["2021\nAnteil ab 80-J�hrige (%)", "2021\nAnteil 65- bis 79-J�hrige (%)", "2021\nKaufkraft (Euro/Haushalt)"])))]
econ_df
# Out:
#             Bundesland                          Kommune       GKZ  \
# 0      Rheinland-Pfalz                    Ahrweiler, LK   7131000
# 1               Bayern            Aichach-Friedberg, LK   9771000
# 2    Baden-W�rttemberg              Alb-Donau-Kreis, LK   8425000
# 3            Th�ringen             Altenburger Land, LK  16077000
# 4      Rheinland-Pfalz    Altenkirchen (Westerwald), LK   7132000
# ..                 ...                              ...       ...
# 289      Niedersachsen                 Wolfenb�ttel, LK   3158000
# 290             Bayern  Wunsiedel im Fichtelgebirge, LK   9479000
# 291             Bayern                     W�rzburg, LK   9679000
# 292  Baden-W�rttemberg              Zollernalbkreis, LK   8417000
# 293            Sachsen                      Zwickau, LK  14524000
#
#      2021\nHaushalte mit niedrigem Einkommen (%)  \
# 0                                           38.7
# 1                                           28.1
# 2                                           31.8
# 3                                           53.6
# 4                                           41.8
# ..                                           ...
# 289                                         43.2
# 290                                         45.6
# 291                                         39.0
# 292                                         32.9
# 293                                         51.6
#
#      2021\nAllgemeine Deckungsmittel (Euro je Einwohner:in)  \
# 0                                                1.597
# 1                                                1.798
# 2                                                1.946
# 3                                                1.758
# 4                                                1.657
# ..                                                 ...
# 289                                              1.810
# 290                                              1.938
# 291                                              1.702
# 292                                              1.999
# 293                                              1.676
#
#      2021\nAnteil ab 65-J�hrige (%)  \
# 0                              25.1
# 1                              20.4
# 2                              19.9
# 3                              31.7
# 4                              23.0
# ..                              ...
# 289                            24.4
# 290                            26.8
# 291                            22.5
# 292                            22.6
# 293                            30.0
#
#      2021\nVerschuldung im Kernhaushalt (Euro je Einwohner:in)           ARS
# 0                                                1.743           71310000000
# 1                                              621.000           97710000000
# 2                                              425.000           84250000000
# 3                                              577.000          160770000000
# 4                                                2.463           71320000000
# ..                                                 ...                   ...
# 289                                              1.616           31580000000
# 290                                              2.553           94790000000
# 291                                            712.000           96790000000
# 292                                            583.000           84170000000
# 293                                            346.000          145240000000
#
# [294 rows x 8 columns]

# %%
# normalize the factors
for col in econ_df.columns:
    if "2021" not in col:
        continue
    econ_df[f"{col}_normalized"] = econ_df[col] / econ_df[col].max()

econ_df["socio_economic_index"] = econ_df["2021\nHaushalte mit niedrigem Einkommen (%)_normalized"] + econ_df["2021\nAnteil ab 65-J�hrige (%)_normalized"] + econ_df["2021\nVerschuldung im Kernhaushalt (Euro je Einwohner:in)_normalized"] - econ_df["2021\nAllgemeine Deckungsmittel (Euro je Einwohner:in)_normalized"]

# %%
econ_df["socio_economic_index"]
# Out:
# 0      1.140881
# 1      1.378304
# 2      1.198231
# 3      2.169856
# 4      1.118783
#          ...
# 289    1.152787
# 290    1.244335
# 291    1.759899
# 292    1.451611
# 293    1.864114
# Name: socio_economic_index, Length: 294, dtype: float64

# %%
econ_df.to_csv("data/socioeconomic_factors_new.csv")
